# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoGamaJ/Python---DataScience/blob/main/An%C3%A1lise_explorat%C3%B3ria_01_ProUni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib
#import csv

# %%
prouni_geral = pd.read_csv("/content/ProuniRelatorioDadosAbertos2020.csv", sep=";", encoding="ISO-8859-1")

prouni_geral
# Out:
#         ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 0                      2020                    322
# 1                      2020                    163
# 2                      2020                  17670
# 3                      2020                    203
# 4                      2020                    203
# ...                     ...                    ...
# 166825                 2020                   1491
# 166826                 2020                   1491
# 166827                 2020                   1491
# 166828                 2020                   1491
# 166829                 2020                   1491
#
#                             NOME_IES_BOLSA     MUNICIPIO  \
# 0                    UNIVERSIDADE PAULISTA      IPATINGA
# 1               UNIVERSIDADE ESTµCIO DE Sµ     FORTALEZA
# 2                FACULDADE DE QUIXERAMOBIM  QUIXERAMOBIM
# 3             UNIVERSIDADE SÇO JUDAS TADEU     SAO PAULO
# 4             UNIVERSIDADE SÇO JUDAS TADEU     SAO PAULO
# ...

# %%
prouni_geral.head()
# Out:
#    ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA                NOME_IES_BOLSA  \
# 0                 2020                    322         UNIVERSIDADE PAULISTA
# 1                 2020                    163    UNIVERSIDADE ESTµCIO DE Sµ
# 2                 2020                  17670     FACULDADE DE QUIXERAMOBIM
# 3                 2020                    203  UNIVERSIDADE SÇO JUDAS TADEU
# 4                 2020                    203  UNIVERSIDADE SÇO JUDAS TADEU
#
#       MUNICIPIO                            CAMPUS TIPO_BOLSA  \
# 0      IPATINGA                          IPATINGA   INTEGRAL
# 1     FORTALEZA               EAD VIA CORPVS - CE   INTEGRAL
# 2  QUIXERAMOBIM  FACULDADE DE QUIXERAMOBIM - UNIQ   INTEGRAL
# 3     SAO PAULO                          PAULISTA    PARCIAL
# 4     SAO PAULO                          PAULISTA   INTEGRAL
#
#   MODALIDADE_ENSINO_BOLSA NOME_CURSO_BOLSA NOME_TURNO_CURSO_BOLSA  \
# 0                     EAD        PEDAGOGIA      CURSO A DIST¶NCIA
# ...

# %%
prouni_geral.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166830 entries, 0 to 166829
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   ANO_CONCESSAO_BOLSA             166830 non-null  int64
#  1   CODIGO_EMEC_IES_BOLSA           166830 non-null  int64
#  2   NOME_IES_BOLSA                  166830 non-null  object
#  3   MUNICIPIO                       166830 non-null  object
#  4   CAMPUS                          166830 non-null  object
#  5   TIPO_BOLSA                      166830 non-null  object
#  6   MODALIDADE_ENSINO_BOLSA         166830 non-null  object
#  7   NOME_CURSO_BOLSA                166792 non-null  object
#  8   NOME_TURNO_CURSO_BOLSA          166830 non-null  object
#  9   CPF_BENEFICIARIO                166830 non-null  object
#  10  SEXO_BENEFICIARIO               166830 non-null  object
#  11  RACA_BENEFICIARIO               166830 non-null  object
# ...

# %%
prouni_geral.describe()
# Out:
#        ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA
# count             166830.0          166830.000000
# mean                2020.0            2270.745022
# std                    0.0            4063.329275
# min                 2020.0              10.000000
# 25%                 2020.0             322.000000
# 50%                 2020.0            1196.000000
# 75%                 2020.0            1952.000000
# max                 2020.0           24488.000000

# %%
prouni_geral.columns.values
# Out:
# array(['ANO_CONCESSAO_BOLSA', 'CODIGO_EMEC_IES_BOLSA', 'NOME_IES_BOLSA',
#        'MUNICIPIO', 'CAMPUS', 'TIPO_BOLSA', 'MODALIDADE_ENSINO_BOLSA',
#        'NOME_CURSO_BOLSA', 'NOME_TURNO_CURSO_BOLSA', 'CPF_BENEFICIARIO',
#        'SEXO_BENEFICIARIO', 'RACA_BENEFICIARIO', 'DATA_NASCIMENTO',
#        'BENEFICIARIO_DEFICIENTE_FISICO', 'REGIAO_BENEFICIARIO',
#        'UF_BENEFICIARIO', 'MUNICIPIO_BENEFICIARIO'], dtype=object)

# %%
prouni_geral.iloc[1000]
# Out:
# ANO_CONCESSAO_BOLSA                                                2020
# CODIGO_EMEC_IES_BOLSA                                              1491
# NOME_IES_BOLSA                       CENTRO UNIVERSITµRIO INTERNACIONAL
# MUNICIPIO                                                       CARUARU
# CAMPUS                                                      PAP CARUARU
# TIPO_BOLSA                                                     INTEGRAL
# MODALIDADE_ENSINO_BOLSA                                             EAD
# NOME_CURSO_BOLSA                  ANµLISE E DESENVOLVIMENTO DE SISTEMAS
# NOME_TURNO_CURSO_BOLSA                                CURSO A DIST¶NCIA
# CPF_BENEFICIARIO                                         110.XXX.XXX-00
# SEXO_BENEFICIARIO                                                     F
# RACA_BENEFICIARIO                                                 Preta
# DATA_NASCIMENTO                                              28/09/1993
# ...

# %%
prouni_geral['NOME_CURSO_BOLSA']
# Out:
# 0                       PEDAGOGIA
# 1                       MARKETING
# 2                        FARMµCIA
# 3                         DIREITO
# 4                         DIREITO
#                    ...
# 166825              ADMINISTRAÇO
# 166826    RELAåES INTERNACIONAIS
# 166827              ADMINISTRAÇO
# 166828    RELAåES INTERNACIONAIS
# 166829                     MéSICA
# Name: NOME_CURSO_BOLSA, Length: 166830, dtype: object

# %%
prouni_geral[prouni_geral['NOME_CURSO_BOLSA'] == "ANµLISE E DESENVOLVIMENTO DE SISTEMAS"]
# Out:
#         ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 71                     2020                    344
# 225                    2020                    322
# 467                    2020                    203
# 469                    2020                   1491
# 473                    2020                   1491
# ...                     ...                    ...
# 166533                 2020                   1491
# 166546                 2020                   1107
# 166556                 2020                   1491
# 166574                 2020                    322
# 166756                 2020                    322
#
#                                NOME_IES_BOLSA            MUNICIPIO  \
# 71                   CENTRO UNIVERSITµRIO UNA       BELO HORIZONTE
# 225                     UNIVERSIDADE PAULISTA           ARARAQUARA
# 467              UNIVERSIDADE SÇO JUDAS TADEU            SAO PAULO
# 469        CENTRO UNIVERSITµRIO INTERNACIONAL         CAMPO MOURAO
# ...

# %%
prouni_geral[(prouni_geral['NOME_CURSO_BOLSA'] == "ANµLISE E DESENVOLVIMENTO DE SISTEMAS") & (prouni_geral['RACA_BENEFICIARIO'] == "Preta")]
# Out:
#         ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 467                    2020                    203
# 637                    2020                   1255
# 765                    2020                   1491
# 1000                   2020                   1491
# 1001                   2020                   1491
# ...                     ...                    ...
# 164271                 2020                    163
# 164272                 2020                    163
# 165615                 2020                    163
# 165805                 2020                    322
# 165982                 2020                    163
#
#                             NOME_IES_BOLSA     MUNICIPIO  \
# 467           UNIVERSIDADE SÇO JUDAS TADEU     SAO PAULO
# 637         CENTRO UNIVERSITµRIO FBV WYDEN        RECIFE
# 765     CENTRO UNIVERSITµRIO INTERNACIONAL     SAO PAULO
# 1000    CENTRO UNIVERSITµRIO INTERNACIONAL       CARUARU
# 1001    CENTRO UNIVERSITµRIO INTERNACIONAL        ILHEUS
# ...

# %%
prouni_geral["NOME_CURSO_BOLSA"].value_counts()
# Out:
# DIREITO                                               15082
# ADMINISTRAÇO                                         14888
# PEDAGOGIA                                             13660
# ENFERMAGEM                                             9234
# CIÒNCIAS CONTµBEIS                                     8570
#                                                       ...
# SOLDAGEM                                                  1
# TRADUÇO E INTERPRETAÇO                                  1
# SECRETARIADO EXECUTIVO BILINGUE - PORTUGUÒS/INGLÒS        1
# PROCESSOS METALéRGICOS                                    1
# COMPUTAÇO GRµFICA                                        1
# Name: NOME_CURSO_BOLSA, Length: 317, dtype: int64

# %%
prouni_geral["MUNICIPIO"].value_counts()
# Out:
# SAO PAULO           0.111868
# BELO HORIZONTE      0.034232
# BRASILIA            0.027459
# CURITIBA            0.026020
# SAO LUIS            0.023089
#                       ...
# URUCUI              0.000006
# SANDOVALINA         0.000006
# CORONEL SAPUCAIA    0.000006
# CAMPESTRE           0.000006
# ITAQUIRAI           0.000006
# Name: MUNICIPIO, Length: 1434, dtype: float64

# %%
prouni_geral["MUNICIPIO"].value_counts(normalize=True)
# Out:
# SAO PAULO           0.111868
# BELO HORIZONTE      0.034232
# BRASILIA            0.027459
# CURITIBA            0.026020
# SAO LUIS            0.023089
#                       ...
# URUCUI              0.000006
# SANDOVALINA         0.000006
# CORONEL SAPUCAIA    0.000006
# CAMPESTRE           0.000006
# ITAQUIRAI           0.000006
# Name: MUNICIPIO, Length: 1434, dtype: float64

# %%
# Valores unicos contidos na coluna                               --- .unique()
prouni_geral["NOME_CURSO_BOLSA"].unique()
# Out:
# array(['PEDAGOGIA', 'MARKETING', 'FARMµCIA', 'DIREITO',
#        'MEDICINA VETERINµRIA', 'ODONTOLOGIA', 'GESTÇO COMERCIAL',
#        'GESTÇO DE RECURSOS HUMANOS', 'ENGENHARIA CIVIL',
#        'CIÒNCIAS CONTµBEIS', 'ADMINISTRA\x80ÇO', 'PROCESSOS GERENCIAIS',
#        'GESTÇO AMBIENTAL', 'NUTRI\x80ÇO', 'HISTàRIA',
#        'EST\x90TICA E COSM\x90TICA', 'BIOMEDICINA', 'FISIOTERAPIA',
#        'ENFERMAGEM', 'COMUNICA\x80ÇO SOCIAL - JORNALISMO',
#        'SISTEMAS DE INFORMA\x80ÇO', 'EDUCA\x80ÇO FÖSICA',
#        'DESIGN DE INTERIORES', 'ANµLISE E DESENVOLVIMENTO DE SISTEMAS',
#        'ENGENHARIA DE PRODU\x80ÇO', 'ENGENHARIA MEC¶NICA',
#        'SERVI\x80O SOCIAL', 'CIÒNCIAS DA COMPUTA\x80ÇO', 'LOGÖSTICA',
#        'PSICOLOGIA', 'GESTÇO DA PRODU\x80ÇO INDUSTRIAL',
#        'RELA\x80åES INTERNACIONAIS', 'ARTES VISUAIS',
#        'PUBLICIDADE E PROPAGANDA', 'ENGENHARIA QUÖMICA',
#        'ARQUITETURA E URBANISMO', 'ENGENHARIA DE CONTROLE E AUTOMA\x80ÇO',
# ...

# %%
# Quantidade de linhas da coluna
prouni_geral["NOME_CURSO_BOLSA"].shape[0]
# Out:
# 166830

# %%
#
prouni_geral.groupby(["NOME_CURSO_BOLSA"]).mean()
# Out:
#                                              ANO_CONCESSAO_BOLSA  \
# NOME_CURSO_BOLSA
# ACUPUNTURA                                                2020.0
# ADMINISTRAÇO                                             2020.0
# ADMINISTRAÇO DE EMPRESAS                                 2020.0
# ADMINISTRAÇO PéBLICA                                     2020.0
# AGRONEGàCIO                                               2020.0
# ...                                                          ...
# TRADUÇO E INTERPRETAÇO - PORTUGUÒS/INGLÒS               2020.0
# TURISMO                                                   2020.0
# VISAGISMO E TERAPIAS CAPILARES                            2020.0
# ZOOTECNIA                                                 2020.0
# àPTICA E OPTOMETRIA                                       2020.0
#
#                                              CODIGO_EMEC_IES_BOLSA
# NOME_CURSO_BOLSA
# ACUPUNTURA                                             2076.000000
# ...

# %%
prouni_geral[['RACA_BENEFICIARIO', 'MUNICIPIO_BENEFICIARIO']].apply(lambda x: x.max())
# Out:
# RACA_BENEFICIARIO          Preta
# MUNICIPIO_BENEFICIARIO    ZORTEA
# dtype: object

# %%
prouni_geral["MUNICIPIO"].value_counts().plot(kind="hist")
